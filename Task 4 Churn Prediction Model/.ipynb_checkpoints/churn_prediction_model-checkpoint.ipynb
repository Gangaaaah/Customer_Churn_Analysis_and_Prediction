# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
import joblib

train = pd.read_csv("C:/Users/Shan Sajeer/Documents/Saiket Systems Data science Internship/Customer Churn Analysis and Prediction Project/Data/train.csv")
test = pd.read_csv("C:/Users/Shan Sajeer/Documents/Saiket Systems Data science Internship/Customer Churn Analysis and Prediction Project/Data/test.csv")

train.head()
# Out:
#    customerID  SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# 0  4950-BDEUX              0      35           49.20       1701.65
# 1  7993-NQLJE              0      15           75.10       1151.55
# 2  7321-ZNSLA              0      13           40.55        590.35
# 3  4922-CVPDX              0      26           73.50       1905.70
# 4  2903-YYTBW              0       1           44.55         44.55
#
#    gender_Male  Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True        False           False             False
# 1         True         True            True              True
# 2         True         True            True             False
# 3        False         True           False              True
# 4         True         True            True              True
#
#    MultipleLines_Yes  ...  TechSupport_Yes  StreamingTV_Yes  \
# 0              False  ...            False             True
# 1              False  ...            False            False
# ...

# %%
X_train = train.drop(columns=['Churn_flag'])
y_train = train['Churn_flag']

X_test = test.drop(columns=['Churn_flag'])
y_test = test['Churn_flag']

X_train.shape, X_test.shape
# Out:
# ((5634, 24), (1409, 24))

# %%
X_train = X_train.drop(columns=['customerID'], errors='ignore')
X_test = X_test.drop(columns=['customerID'], errors='ignore')

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Save scaler for later use
joblib.dump(scaler, "scaler.joblib")
# Out:
# ['scaler.joblib']

# %%
log_reg = LogisticRegression(max_iter=1000, class_weight='balanced')
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
rf = RandomForestClassifier(n_estimators=200, class_weight='balanced', random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
models = {
    "Logistic Regression": log_reg,
    "Decision Tree": tree,
    "Random Forest": rf
}

results = []

for name, model in models.items():
    y_pred = model.predict(X_test_scaled if name=="Logistic Regression" else X_test)
    y_prob = model.predict_proba(X_test_scaled if name=="Logistic Regression" else X_test)[:,1]
    
    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-Score": f1_score(y_test, y_pred),
        "ROC-AUC": roc_auc_score(y_test, y_prob)
    })

pd.DataFrame(results)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score   ROC-AUC
# 0  Logistic Regression  0.740241   0.506897  0.786096  0.616352  0.841414
# 1        Decision Tree  0.739532   0.509642  0.494652  0.502035  0.660848
# 2        Random Forest  0.789212   0.632302  0.491979  0.553383  0.827149

# %%
plt.figure(figsize=(8,6))

for name, model in models.items():
    y_prob = model.predict_proba(X_test_scaled if name=="Logistic Regression" else X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.plot(fpr, tpr, label=name)

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend()
plt.show()

# %%
for name, model in models.items():
    y_pred = model.predict(X_test_scaled if name=="Logistic Regression" else X_test)
    cm = confusion_matrix(y_test, y_pred)
    
    print(name)
    print(cm, "\n")
# Out:
# Logistic Regression
# [[749 286]
#  [ 80 294]]
#
# Decision Tree
# [[857 178]
#  [189 185]]
#
# Random Forest
# [[928 107]
#  [190 184]]

# %%
coef = pd.Series(log_reg.coef_[0], index=X_train.columns)
coef.sort_values(key=np.abs, ascending=False).head(15)
# Out:
# tenure                           -1.153424
# MonthlyCharges                   -0.937607
# InternetService_Fiber optic       0.767833
# InternetService_No               -0.657975
# Contract_Two year                -0.620038
# TotalCharges                      0.488735
# Contract_One year                -0.297112
# StreamingMovies_Yes               0.270008
# StreamingTV_Yes                   0.256759
# MultipleLines_Yes                 0.192850
# PaymentMethod_Electronic check    0.188311
# PaperlessBilling_Yes              0.164820
# OnlineSecurity_Yes               -0.122110
# Dependents_Yes                   -0.104808
# TechSupport_Yes                  -0.091712
# dtype: float64

# %%
rf_imp = pd.Series(rf.feature_importances_, index=X_train.columns)
rf_imp.sort_values(ascending=False).head(15)
# Out:
# TotalCharges                      0.176624
# tenure                            0.164241
# MonthlyCharges                    0.163560
# Contract_Two year                 0.061934
# InternetService_Fiber optic       0.049252
# PaymentMethod_Electronic check    0.041123
# Contract_One year                 0.031040
# InternetService_No                0.027665
# PaperlessBilling_Yes              0.026431
# gender_Male                       0.025695
# OnlineSecurity_Yes                0.025358
# TechSupport_Yes                   0.023454
# Partner_Yes                       0.021916
# OnlineBackup_Yes                  0.020799
# Dependents_Yes                    0.019653
# dtype: float64

# %%
joblib.dump(log_reg, "logistic_regression_model.joblib")
joblib.dump(tree, "decision_tree_model.joblib")
joblib.dump(rf, "random_forest_model.joblib")
# Out:
# ['random_forest_model.joblib']
